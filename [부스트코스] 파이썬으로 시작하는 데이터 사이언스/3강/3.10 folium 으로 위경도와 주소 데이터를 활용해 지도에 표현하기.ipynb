# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('axes', unicode_minus=False)

from IPython.display import set_matplotlib_formats

set_matplotlib_formats('retina')

df = pd.read_csv('../data/소상공인시장진흥공단_상가업소정보_의료기관_201909.csv', low_memory=False)

plt.rc('font', family='Malgun Gothic')

# %matplotlib inline

# %%
import folium

folium.Map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_seoul_hospital = df[(df["상권업종소분류명"] == "종합병원") & (df["시도명"] == "서울특별시")].copy()
df_seoul_hospital["위도"].mean()
# Out:
# 37.54244715656364

# %%
df_seoul_hospital["경도"].mean()
# Out:
# 127.00850537565638

# %%
df_seoul_hospital.tail(1)
# Out:
#          상가업소번호     상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 90788  16162338  성베드로병원  NaN         S       의료       S01       병원    S01B01
#
#       상권업종소분류명 표준산업분류코드  ...                     건물관리번호    건물명  \
# 90788     종합병원   Q86101  ...  1168011800109100027000895  베드로병원
#
#                       도로명주소     구우편번호   신우편번호  동정보  층정보  호정보          경도  \
# 90788  서울특별시 강남구 남부순환로 2649  135859.0  6271.0  NaN  NaN  NaN  127.039567
#
#               위도
# 90788  37.485604
#
# [1 rows x 39 columns]

# %%
map = folium.Map(location=[df_seoul_hospital["위도"].mean(),df_seoul_hospital["경도"].mean()], zoom_start=12)

for n in df_seoul_hospital.index:
    name = df_seoul_hospital.loc[n, "상호명"]
    address = df_seoul_hospital.loc[n, "도로명주소"]
    popup = f"{name}-{address}"
    location = [df_seoul_hospital.loc[n, "위도"], df_seoul_hospital.loc[n, "경도"]]
    folium.Marker(
        location = location,
        popup = popup,
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_seoul_language = df[(df["상권업종소분류명"] == "언어치료") & (df["시도명"] == "서울특별시")].copy()

# %%
map = folium.Map(location=[df_seoul_language["위도"].mean(),df_seoul_language["경도"].mean()], zoom_start=12)

for n in df_seoul_language.index:
    name = df_seoul_language.loc[n, "상호명"]
    address = df_seoul_language.loc[n, "도로명주소"]
    popup = f"{name}-{address}"
    location = [df_seoul_language.loc[n, "위도"], df_seoul_language.loc[n, "경도"]]
    folium.Marker(
        location = location,
        popup = popup,
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_seoul_curecenter = df[(df["상권업종소분류명"] == "피부과") & (df["시도명"] == "서울특별시")].copy()

# %%
map = folium.Map(location=[df_seoul_curecenter["위도"].mean(),df_seoul_curecenter["경도"].mean()], zoom_start=12)

for n in df_seoul_curecenter.index:
    name = df_seoul_curecenter.loc[n, "상호명"]
    address = df_seoul_curecenter.loc[n, "도로명주소"]
    popup = f"{name}-{address}"
    location = [df_seoul_curecenter.loc[n, "위도"], df_seoul_curecenter.loc[n, "경도"]]
    folium.Marker(
        location = location,
        popup = popup,
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_seoul_plasticsurgery = df[(df["상권업종소분류명"] == "정형/성형외과") & (df["시도명"] == "서울특별시")].copy()

# %%
map = folium.Map(location=[df_seoul_plasticsurgery["위도"].mean(),df_seoul_plasticsurgery["경도"].mean()], zoom_start=12)

for n in df_seoul_plasticsurgery.index:
    name = df_seoul_plasticsurgery.loc[n, "상호명"]
    address = df_seoul_plasticsurgery.loc[n, "도로명주소"]
    popup = f"{name}-{address}"
    location = [df_seoul_plasticsurgery.loc[n, "위도"], df_seoul_plasticsurgery.loc[n, "경도"]]
    folium.Marker(
        location = location,
        popup = popup,
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import numpy as np

# %% [markdown]
# #### Arrary operations

# %%
test_a = np.array([[1,2,3],[4,5,6]], float)

# %%
test_a + test_a
# Out:
# array([[ 2.,  4.,  6.],
#        [ 8., 10., 12.]])

# %%
test_a - test_a
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
test_a * test_a
# Out:
# array([[ 1.,  4.,  9.],
#        [16., 25., 36.]])

# %%
matrix_a = np.arange(1,13).reshape(3,4)
matrix_a * matrix_a
# Out:
# array([[  1,   4,   9,  16],
#        [ 25,  36,  49,  64],
#        [ 81, 100, 121, 144]])

# %% [markdown]
# #### dot product

# %%
test_a = np.arange(1,7).reshape(2,3)
test_b = np.arange(7,13).reshape(3,2)

# %%
test_a.dot(test_b)
# Out:
# array([[ 58,  64],
#        [139, 154]])

# %%
test_a = np.arange(1,7).reshape(2,3)
test_a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
test_a.transpose()
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
test_a.T
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
test_a.T.dot(test_a)
# Out:
# array([[17, 22, 27],
#        [22, 29, 36],
#        [27, 36, 45]])

# %% [markdown]
# #### broadcasting

# %%
test_matrix = np.array([[1,2,3],[4,5,6]], float)
scalar = 3

# %%
test_matrix + scalar
# Out:
# array([[4., 5., 6.],
#        [7., 8., 9.]])

# %%
test_matrix - scalar
# Out:
# array([[-2., -1.,  0.],
#        [ 1.,  2.,  3.]])

# %%
test_matrix * 5
# Out:
# array([[ 5., 10., 15.],
#        [20., 25., 30.]])

# %%
test_matrix / 5
# Out:
# array([[0.2, 0.4, 0.6],
#        [0.8, 1. , 1.2]])

# %%
test_matrix // 0.2
# Out:
# array([[ 4.,  9., 14.],
#        [19., 24., 29.]])

# %%
test_matrix ** 2
# Out:
# array([[ 1.,  4.,  9.],
#        [16., 25., 36.]])

# %%
test_matrix = np.arange(1,13).reshape(4,3)
test_vector = np.arange(10,40,10)
test_matrix+ test_vector
# Out:
# array([[11, 22, 33],
#        [14, 25, 36],
#        [17, 28, 39],
#        [20, 31, 42]])

# %% [markdown]
# #### numpy performance

# %%
def sclar_vector_product(scalar, vector):
    result = []

    for value in vector:
        result.append(scalar * value)
    
    return result 

iternation_max = 100000000

vector = list(range(iternation_max))
scalar = 2

# %timeit sclar_vector_product(scalar, vector)
# Out:
# 9.18 s ± 73.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit [scalar * value for value in range(iternation_max)]
# %timeit np.arange(iternation_max) * scalar
# Out:
# 9.1 s ± 33.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 358 ms ± 1.57 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
